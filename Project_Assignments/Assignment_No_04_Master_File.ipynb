# %% [markdown]
# # Install the Package

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# # Question no 01

# %% [raw]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")


# Opening the Required URL of "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos".

url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
# Creating the Empty List.

Common_list_Container = []
Rank_ = []
Video_name = []
Artist_name = []
Upload_date = []
Views_ = []

# Scraping " Common_ " items having same class name.

Common_list_Container_tag = driver.find_elements(By.XPATH,'//td')
for i in Common_list_Container_tag[2:181]:
    common=i.text
    Common_list_Container.append(common)
    
print(len(Common_list_Container))


# Slicing and Indexing of list

Rank_ = Common_list_Container[0::6]
Video_name = Common_list_Container[1::6]
Artist_name = Common_list_Container[2::6]
Views_ = Common_list_Container[3::6]
Upload_date = Common_list_Container[4::6]

# finding length .
print(len(Rank_),len(Video_name),len(Artist_name),len(Views_),len(Upload_date))
# Out:
# 179
# 30 30 30 30 30

# %%
# Making the Data Frame for the above details .

df=pd.DataFrame({'RANK':Rank_,'VIDEO NAME':Video_name,'ARTIST NAME':Artist_name,'VIEW COUNTS':Views_,'DATE_OF_RELEASE':Upload_date})
df
# Out:
#    RANK                                       VIDEO NAME  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                                "Uptown Funk"[24]
# 8    9.                          "Wheels on the Bus"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %%
# Saving the Data to CSV format.

df.to_csv('List of most-viewed YouTube videos1.csv',index=False)

# The Files will be saved to the jupyter notebook , with the name as " raw_data.csv" file.

# %% [markdown]
# # Question no 02

# %% [raw]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")


# Opening the Required URL of "https://www.bcci.tv/"

url = "https://www.bcci.tv/"
driver.get(url)

# %%
# Creating the empty list.

Match_title_ = []
Series_ = []
Place_ = []
Date_ = []
Time_ = []

# Click on internationaL Button

international_button = driver.find_element(By.XPATH,'//li[@class="nav-item"]')
international_button.click()

# %%
# Click on All Format button

all_format_button = driver.find_element(By.XPATH,'//div[@class="customSelecBox matchFormatDropDown"]')
all_format_button.click()

# Click on ODI button

select_odi_button = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[2]/div[3]')
select_odi_button.click()

# %%
# Creating empty list
first_odi = []
series3items = []
date3items = []
time3items = []
place3items = []


# Scraping , in one common list name as "first_odi" for 1st odi only.
match_title_tag = driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
for i in match_title_tag[:]:
    title=i.text
    Match_title_.append(title)
    
first_odi  = Match_title_ [0::3]


# Scraping , in one common list name as "series3items" for 1st odi only.
series_tag = driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
for i in series_tag[:]:
    series=i.text
    Series_.append(series)
    
series3items = Series_[0::3]


# Scraping , in one common list name as "date3items" for 1st odi only.

date_tag = driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
for i in date_tag[:]:
    date=i.text
    Date_.append(date)
    
date3items = Date_[0::3]


# Scraping , in one common list name as "time3items" for 1st odi only.

time_tag = driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
for i in time_tag[:]:
    time=i.text
    Time_.append(time)
    
time3items = Time_[0::3]


# Scraping , in one common list name as "place3items" for 1st odi only.

place_tag = driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
for i in place_tag[:]:
    place=i.text
    Place_.append(place)
    
place3items = Place_[0::3]

print(len(first_odi),len(series3items),len(date3items),len(time3items),len(place3items))
# Out:
# 3 3 3 3 3

# %%
# Making the Data Frame for the above details . ONLY FOR :_ 1st ODI 

df=pd.DataFrame({'Seq_NO':range(1,4,1),'MATCH_TITLE':first_odi,'SERIES_NAME':series3items,'PLACE':place3items,'TIMINGS':time3items,'DATE':date3items})
df
# Out:
#    Seq_NO MATCH_TITLE                                   SERIES_NAME  \
# 0       1   1st ODI -    SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 1       2   1st ODI -  NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 2       3   1st ODI -    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
#
#                                  PLACE      TIMINGS         DATE
# 0           Barsapara Cricket Stadium,  1:30 PM IST  10 JAN 2023
# 1  Rajiv Gandhi International Stadium,  1:30 PM IST  18 JAN 2023
# 2                    Wankhede Stadium,  1:30 PM IST  17 MAR 2023

# %%
# Making the Data Frame for the above details . ALL IN ONE DECLATRION 

df1=pd.DataFrame({'Seq_NO':range(1,10,1),'MATCH_TITLE':Match_title_,'SERIES_NAME':Series_,'PLACE':Place_,'TIMINGS':Time_,'DATE':Date_})
df1
# Out:
#    Seq_NO MATCH_TITLE                                   SERIES_NAME  \
# 0       1   1st ODI -    SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 1       2   2nd ODI -    SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 2       3   3rd ODI -    SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 3       4   1st ODI -  NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 4       5   2nd ODI -  NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 5       6   3rd ODI -  NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 6       7   1st ODI -    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 7       8   2nd ODI -    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 8       9   3rd ODI -    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
#
#                                                PLACE      TIMINGS         DATE
# 0                         Barsapara Cricket Stadium,  1:30 PM IST  10 JAN 2023
# 1                                      Eden Gardens,  1:30 PM IST  12 JAN 2023
# ...

# %%
# Saving the Data to CSV format.

df1.to_csv('ODI Matches list of all Combine1.csv',index=False)

# The Files will be saved to the jupyter notebook , with the name as " ODI Matches list of all Combine.csv" file.

# %% [markdown]
# # Question No 03

# %% [raw]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")


# Opening the Required URL of "https://www.guru99.com/"

url = "https://www.guru99.com/"
driver.get(url)

# %%
# Click on 'selenium_button'

selenium_button = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a')
selenium_button.click()

# %%
# Click on 'tutorial_seleniumexception_button'

tutorial_seleniumexception_button = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a')
tutorial_seleniumexception_button.click()

# %%
# Creating the empty list.

Name_Of_Exception = []
Description_ = []


# Scraping  items at once, in "Name_Of_Exception" .

name_exception_tag = driver.find_elements(By.XPATH,'//strong')
for i in name_exception_tag[2:43]:
    name=i.text
    Name_Of_Exception.append(name)
    
    
# Scraping items at once, in "Description_" .

description_details_tag = driver.find_elements(By.XPATH,'//p')
for i in description_details_tag[2:43]:
    desc=i.text
    Description_.append(desc)
    
# Printning the descriptions of the exceptions.
print(Description_)
# Out:
# ['1. ElementNotVisibleException: This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.', '2. ElementNotSelectableException: This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.', '3. NoSuchElementException: This Exception occurs if an element could not be found.', '4. NoSuchFrameException: This Exception occurs if the frame target to be switched to does not exist.', '5. NoAlertPresentException: This Exception occurs when you switch to no presented alert.', '6. NoSuchWindowException: This Exception occurs if the window target to be switch does not exist.', '7. StaleElementReferenceException: This Selenium exception occurs happens when the web element is detached from the current DOM.', '8. SessionNotFoundException: The WebDriver is acting after you quit the browser.', '9. TimeoutException: Thrown when there is not enough time for a command to be co
# ...

# %%
# Making the Data Frame for " Name_of_Exceptions and Their_Details_Descriptions" . 

df=pd.DataFrame({'NAME_OF_EXCEPTIONS':Name_Of_Exception,'DESCRIPTION_DETAILS':Description_ })
df
# Out:
#                           NAME_OF_EXCEPTIONS  \
# 0             1. ElementNotVisibleException:
# 1          2. ElementNotSelectableException:
# 2                 3. NoSuchElementException:
# 3                   4. NoSuchFrameException:
# 4                5. NoAlertPresentException:
# 5                  6. NoSuchWindowException:
# 6         7. StaleElementReferenceException:
# 7               8. SessionNotFoundException:
# 8                       9. TimeoutException:
# 9                    10. WebDriverException:
# 10            11. ConnectionClosedException:
# 11     12. ElementClickInterceptedException:
# 12      13. ElementNotInteractableException:
# 13             14. ErrorInResponseException:
# 14  15. ErrorHandler.UnknownServerException:
# 15         16. ImeActivationFailedException:
# 16             17. ImeNotAvailableException:
# 17         18. InsecureCertificateException:
# 18             19. InvalidArgumentException:
# 19         20. InvalidCookieDomainException:
# ...

# %% [markdown]
# # Question no 04

# %% [raw]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")

# Opening the Required URL of "http://statisticstimes.com/"
url = "http://statisticstimes.com/"
driver.get(url)

# %%
economy_page = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy_page.click()

# %%
economy_page = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
economy_page.click()

# %%
economy_page = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
economy_page.click()

# %%
# Creating the Empty Lists.

RANK_ = []
STATE_ = []

Data_Common_Container= []
gsdp_18_19_data = []

SHARE_ = []
GDP_ = []

# %%
# Scraping items , in list name as "RANK_" .

rank_tag = driver.find_elements(By.XPATH,'//td[@class="data1"]')
for i in rank_tag[0:33]:
    rank=i.text
    RANK_.append(rank)
    
# Scraping items , in list name as "STATE_ = []" .

state_tag = driver.find_elements(By.XPATH,'//td[@class="name"]')
for i in state_tag[0:33]:
    state=i.text
    STATE_.append(state)
    
# Scraping items, in list name as "Data_Common_Container= []" .

data_common_tag = driver.find_elements(By.XPATH,'//td[@class="data"]')
for i in data_common_tag[0:165]:
    common=i.text
    Data_Common_Container.append(common)
    
gsdp_19_20_data = Data_Common_Container[0::5]

# Scraping all the desired items at once, in one common list name as "gsdp_18_19_data = []" .

gsdp_18_19_tag = driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]')
for i in gsdp_18_19_tag[0:33]:
    gsdp_18_19=i.text
    gsdp_18_19_data.append(gsdp_18_19)
    
SHARE_ = Data_Common_Container[1::5]

GDP_ = Data_Common_Container[2::5]

print(len(RANK_),len(STATE_),len(Data_Common_Container),len(gsdp_19_20_data),len(gsdp_18_19_data),len(SHARE_),len(GDP_))
# Out:
# 33 33 165 33 33 33 33

# %%
# Making the Data Frame for the above details .

df=pd.DataFrame({'RANK':RANK_,'STATE_NAME':STATE_,'GSDP_18-19_':gsdp_18_19_data,'GSDP_19-20_':gsdp_19_20_data,'SHARE_PERCENT':SHARE_,'GDP_IN_BILLION':GDP_})
df
# Out:
#    RANK                 STATE_NAME GSDP_18-19_ GSDP_19-20_ SHARE_PERCENT  \
# 0     1                Maharashtra   2,632,792           -        13.94%
# 1     2                 Tamil Nadu   1,630,208   1,845,853         8.63%
# 2     3              Uttar Pradesh   1,584,764   1,687,818         8.39%
# 3     4                    Gujarat   1,502,899           -         7.96%
# 4     5                  Karnataka   1,493,127   1,631,977         7.91%
# 5     6                West Bengal   1,089,898   1,253,832         5.77%
# 6     7                  Rajasthan     942,586   1,020,989         4.99%
# 7     8             Andhra Pradesh     862,957     972,782         4.57%
# 8     9                  Telangana     861,031     969,604         4.56%
# 9    10             Madhya Pradesh     809,592     906,672         4.29%
# 10   11                     Kerala     781,653           -         4.14%
# 11   12                      Delhi     774,870     856,112         4.10%
# ...

# %% [markdown]
# # Question no 05

# %% [raw]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# ASSIGNMENT
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the Required URL of "https://github.com/"
url = "https://github.com/"
driver.get(url)

# %%
# Creating the Empty lists.

Repository_title = []
Repository_description = []
Contributors_count = []
Language_used = []

# %%
# Click on to the "OpenSource Icon".

open_source_bttn = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')
open_source_bttn.click()

# Click on to the "trending_bttn Icon".

trending_bttn = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')
trending_bttn.click()

# %%
# Scraping items, in list name as "Repository_title" .

Repository_title_tag = driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
for i in Repository_title_tag[0:25]:
    reponame=i.text
    Repository_title.append(reponame)

print(len(Repository_title))
print(Repository_title)
# Out:
# 25
# ['LAION-AI / Open-Assistant', 'karpathy / nanoGPT', 'sczhou / CodeFormer', 'DarkFlippers / unleashed-firmware', 'ytdl-org / youtube-dl', 'google / osv-scanner', 'pola-rs / polars', 'neonbjb / tortoise-tts', 'Developer-Y / cs-video-courses', 'dair-ai / Prompt-Engineering-Guide', 'Ebazhanov / linkedin-skill-assessments-quizzes', 'ocornut / imgui', 'AmruthPillai / Reactive-Resume', 'PRQL / prql', 'A-poc / RedTeam-Tools', 'jerryjliu / gpt_index', 'imDazui / Tvlist-awesome-m3u-m3u8', 'aurae-runtime / aurae', 'zlib-searcher / zlib-searcher', 'BrunoLevy / learn-fpga', 'alist-org / alist', 'freeCodeCamp / freeCodeCamp', 'Atlas-OS / Atlas', 'SheerSt / pokewilds', 'jwasham / coding-interview-university']

# %%
# Scraping items, in list name as "Repository_description" .

Repository_description_tag = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in Repository_description_tag[0:25]:
    repodisc=i.text
    Repository_description.append(repodisc)
    
print(len(Repository_description))
print(Repository_description)
# Out:
# 25
# ...

# %%
# Created empty list as "product_urls"  , to store urls.
product_urls = []


# Scrapping all producct urls.
urls = driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
for i in urls[:25]:
    product_urls.append(i.get_attribute('href'))                             #appending the urls, in product_urls lists.

print(len(product_urls))
print(product_urls)
# Out:
# 25
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# # Question no 06

# %% [raw]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the Required URL of "https://maps.google.com"
url = "https:/www.billboard.com/"
driver.get(url)

# %%
charts_bttn = driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
charts_bttn.click()

# %%
view_chart_bttn = driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
view_chart_bttn.click()

# %%
# Creating the Empty lists.

Song_name = []
Artist_name = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

Common_list = []

Common_list2 = []

# %%
# Scraping "Song_Name"  .

Common_list_tag = driver.find_elements(By.XPATH,'//h3[@id="title-of-a-story"]')
for i in Common_list_tag[0:403]:
    common=i.text
    Common_list.append(common)
    
Song_name = Common_list [6::4]

# %%
# Scraping "Artist_name" .

Artist_name_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"]')
for i in Artist_name_tag[:]:
    art=i.text
    Artist_name.append(art)
    

Artist_name_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
for i in Artist_name_tag[0:99]:
    art=i.text
    Artist_name.append(art)

# %%
# Scraping items, in list name as "Common_list2" .

Common_list2_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet"]')
for i in Common_list2_tag[:]:
    common2=i.text
    Common_list2.append(common2)
    
Common_list2_tag = driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]')
for i in Common_list2_tag[0:594]:
    common2=i.text
    Common_list2.append(common2)

# %%
Last_week_rank = Common_list2 [0::6]

Peak_rank = Common_list2 [1::6]

Weeks_on_board = Common_list2 [2::6]

print('hii processing data')
# Out:
# hii processing data

# %%
# Making the Data Frame for the above details .

df=pd.DataFrame({'SEQ_NO':range(1,101,1),'SONG_NAME':Song_name,'ARTIST_NAME':Artist_name,'LAST_WEEK_RANK':Last_week_rank,'PEAK_RANK':Peak_rank,'WEEKS_ON_BOARD':Weeks_on_board})
df
# Out:
#     SEQ_NO                          SONG_NAME                  ARTIST_NAME  \
# 0        1    All I Want For Christmas Is You                 Mariah Carey
# 1        2  Rockin' Around The Christmas Tree                   Brenda Lee
# 2        3                   Jingle Bell Rock                  Bobby Helms
# 3        4            A Holly Jolly Christmas                    Burl Ives
# 4        5                     Last Christmas                        Wham!
# ..     ...                                ...                          ...
# 95      96                          Down Home                 Jimmie Allen
# 96      97                One Thing At A Time                Morgan Wallen
# 97      98                     Hold Me Closer  Elton John & Britney Spears
# 98      99                                Far                          SZA
# 99     100                           All Mine                 Brent Faiyaz
#
#    LAST_WEEK_RANK PEAK_RANK WEEKS_ON_BOARD
# ...

# %% [markdown]
# # Question no 07

# %% [raw]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the URL as "https://www.naukri.com/hr-recruiters-consultants"

url = "https://www.naukri.com/hr-recruiters-consultants"
driver.get(url)

# %%
# entering " Data science " in the search bar.

searchbar = driver.find_element(By.XPATH,'//input[@class="sugInp"]')
searchbar.send_keys("Data science")


# Click in to the Search Bar.

searchbar = driver.find_element(By.XPATH,'//button[@class="fl qsbSrch blueBtn"]')
searchbar.click()

# %%
# Creating the List for Storages of the items.

Common_ = []

Name_ = []
Designation_ = []
Company_ = []
Skills_ = []
Location_ = []

# %%
# Designation Scraping.

Designation_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
for i in Designation_tag[:]:
    desg=i.text
    Designation_.append(desg)
    
# Company Scraping.

Common_tag = driver.find_elements(By.XPATH,'//a[@class="ellipsis"]')
for i in Common_tag[:]:
    com=i.text
    Common_.append(com)
    
Name_ = Common_ [0::2]

Company_ = Common_ [1::2]



# Location Scraping.

Location_tag = driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')
for i in Location_tag[0:30]:
    loca=i.text
    Location_.append(loca)

    
Location_.append('-')

Location_tag = driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')
for i in Location_tag[30:48]:
    loca=i.text
    Location_.append(loca)
    
Location_.append('-')

# Skill_they_Hire_For , Scraping.

Skills_tag = driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
for i in Skills_tag[:]:
    com=i.text
    Skills_.append(com)

# %%
# Making the Data Frame for the above details .

df=pd.DataFrame({'SEQ_NO':range(1,51,1),'NAME':Name_,'DESIGNATION':Designation_,'COMPANY_Name':Company_,'LOCATION':Location_,'SKILLS_THEY_HIRES':Skills_})
df
# Out:
#     SEQ_NO                                           NAME  \
# 0        1                                   Aakash Harit
# 1        2                           shravan Kumar Gaddam
# 2        3                       MARSIAN Technologies LLP
# 3        4                                   Anik Agrawal
# 4        5                                   subhas patel
# 5        6   Abhishek - Only Analytics Hiring - India and
# 6        7  Institute for Financial Management and Resear
# 7        8                                    Balu Ramesh
# 8        9                                  Asif Lucknowi
# 9       10                                InstaFinancials
# 10      11                                Kalpana Dumpala
# 11      12                                        Mubarak
# 12      13                                 Kushal Rastogi
# 13      14                             Mahesh Babu Channa
# 14      15                             Vaishnavi Kudalkar
# ...

# %% [markdown]
# # Question no 08

# %% [raw]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the URL as "https://www.naukri.com/hr-recruiters-consultants"

url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)

# %%
# Creating One Common List container as " Common_"

Common_ = []
Rank_ = []
Book_name_ = []
Author_name_ = []
Volumes_sold_ = []
Publisher_ = []
Genre_ = []

# %%
# Scraping " Common_ " items having same class name.

Common_tag = driver.find_elements(By.XPATH,'//td[@class="left"]')
for i in Common_tag[:]:
    comm=i.text
    Common_.append(comm)
    
print(len(Common_))

# Slicing "Rank_" .
Rank_ = Common_[0::5]


# Slicing "Book_name_" .
Book_name_ = Common_[1::5]


# Slicing "Author_name_" .
Author_name_ = Common_[2::5]

# Slicing "Volumes_sold_" .
Volumes_sold_ = Common_[3::5]

# Slicing "Publisher_ " .
Publisher_ = Common_[4::5]

# Scraping " Genre_ "
Genre_tag = driver.find_elements(By.XPATH,'//td[@class="last left"]')
for i in Genre_tag[:]:
    genre=i.text
    Genre_.append(genre)

print(len(Rank_),len(Book_name_),len(Author_name_),len(Volumes_sold_),len(Publisher_),len(Genre_))
# Out:
# 500
# 100 100 100 100 100 100

# %%
# Making the Data Frame for the above details .

df=pd.DataFrame({'RANK':Rank_,'BOOK_NAME':Book_name_,'AUTHOR_NAME':Author_name_,'VOLUMES_SOLD':Volumes_sold_,'PUBLICATIONS':Publisher_,'GENERE':Genre_})
df
# Out:
#    RANK                                          BOOK_NAME       AUTHOR_NAME  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
# ...

# %% [markdown]
# # Question no 09

# %% [raw]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the URL as "https://www.naukri.com/hr-recruiters-consultants"

url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
# Creating Empty List.

Name_ = []
Year_span_ = []
Genre_ = []
Run_time_ = []
Ratings_ = []
Votes_ = []

# %%
Name_tag = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
for i in Name_tag[:]:
    name=i.text
    Name_.append(name)
    
Year_span_tag = driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
for i in Year_span_tag[:]:
    yrspan=i.text
    Year_span_.append(yrspan)

Genre_tag = driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in Genre_tag[:]:
    genere=i.text
    Genre_.append(genere)
    
Run_time_tag = driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in Run_time_tag[:]:
    time=i.text
    Run_time_.append(time)
    
Ratings_tag = driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in Ratings_tag[:]:
    rate=i.text
    Ratings_.append(rate)
    
Votes_tag = driver.find_elements(By.XPATH,'//span[@name="nv"]')
for i in Votes_tag[:]:
    vote=i.text
    Votes_.append(vote)
    
    
    
print(len(Name_),len(Year_span_),len(Genre_),len(Run_time_),len(Ratings_),len(Votes_))
# Out:
# 100 100 100 100 100 100

# %%
# Making the Data Frame for the above details .

df=pd.DataFrame({'Ser_No':range(1,101,1),'NAME_OF_SHOW':Name_,'YEAR_SPAN':Year_span_,'GENRE':Genre_,'RUN_TIME':Run_time_,'RATINGS':Ratings_,'VOTES':Votes_})
df
# Out:
#     Ser_No                                    NAME_OF_SHOW    YEAR_SPAN  \
# 0        1                  1. Game of Thrones (2011–2019)  (2011–2019)
# 1        2                     2. Stranger Things (2016– )     (2016– )
# 2        3                 3. The Walking Dead (2010–2022)  (2010–2022)
# 3        4                   4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4        5                          5. The 100 (2014–2020)  (2014–2020)
# ..     ...                                             ...          ...
# 95      96                           96. Reign (2013–2017)  (2013–2017)
# 96      97  97. A Series of Unfortunate Events (2017–2019)  (2017–2019)
# 97      98                     98. Criminal Minds (2005– )     (2005– )
# 98      99           99. Scream: The TV Series (2015–2019)  (2015–2019)
# 99     100          100. The Haunting of Hill House (2018)       (2018)
#
#                        GENRE RUN_TIME RATINGS      VOTES
# ...

# %% [markdown]
# # Question no 10

# %% [raw]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
# Importing the required Libraries.

import selenium 
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException ,ElementNotInteractableException
from selenium.webdriver.common.by import By
import re
import time
import requests
import urllib
import csv


#Lets first connect to the driver-
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
# Opening the URL as "https://www.naukri.com/hr-recruiters-consultants"

url = "https://archive.ics.uci.edu/"
driver.get(url)

# %%
# Creating Empty List.

Common_ = []

Dataset_name_ = []
Data_type_ = []
Task_ = []
Attribute_type_ = []
No_of_instances_ = []
No_of_attribute_ = []
Year_ = []

# %%
viewalldataset = driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]')
viewalldataset.click()

# %%
# Scraping " Common_ " items having same class name.

Common_tag = driver.find_elements(By.XPATH,'//p[@class="normal"]')
for i in Common_tag[8:4362]:
    comm=i.text
    Common_.append(comm)
    
print(len(Common_))
# Out:
# 4354

# %%
Dataset_name_ = Common_[0::7]
    
Data_type_ = Common_[1::7]

Task_ = Common_[2::7]
    
Attribute_type_ = Common_[3::7]
    
No_of_instances_ = Common_[4::7]
    
No_of_attribute_ = Common_[5::7]
    
Year_ = Common_[6::7]
    
      
print(len(Dataset_name_),len(Data_type_),len(Task_),len(Attribute_type_),len(No_of_instances_),len(No_of_attribute_),len(Year_))
# Out:
# 622 622 622 622 622 622 622

# %%
# Making the Data Frame for the above details .Year_

df=pd.DataFrame({'DATASET_NAME':Dataset_name_,'DATA_TYPE':Data_type_,'TASK':Task_,'ATTRIBUTE_TYPE':Attribute_type_,'INSTANCES':No_of_instances_,'ATTRIBUTE':No_of_attribute_,'YEAR':Year_})
df
# Out:
#                                           DATASET_NAME  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       DATA_TYPE                  TASK  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %% [markdown]
# # End_OF_ASSIGNMENT_O4.
